# %% [markdown]
# # 📊 Comparativa de APIs de Noticias
#
# | API             | Límite Gratuito             | Cobertura                  | Datos Proporcionados                                     | Análisis de Sentimiento | Ordenación Disponible            | Idiomas |
# |----------------|----------------------------|----------------------------|----------------------------------------------------------|--------------------------|----------------------------------|---------|
# | **GNews.io**   | 100 solicitudes/día, 10 artículos máx. por solicitud | Noticias generales y tecnológicas | Título, URL, fuente, descripción, imagen                 | ❌ No                     | Relevancia, Fecha                | ✅ Sí |
# | **TheNewsAPI** | 100 solicitudes/día, 3 artículos máx. por solicitud  | Noticias generales            | Título, URL, fuente, resumen                             | ❌ No                     | Relevancia, Fecha                | ✅ Sí |

# %%
from bs4 import BeautifulSoup
import os

# %%
# API Keys
GNEWS_API_KEY = "087e2241d8a55daf522083c0ddab7547"
THENEWS_API_KEY = "PBqwcAoCbsLtDB2FF8NQNxpjOEeGQSkzu4tGB79E"

# %%
# Utility functions
def format_duration(td):
    total_seconds = int(td.total_seconds())
    hours = total_seconds // 3600
    minutes = (total_seconds % 3600) // 60
    seconds = total_seconds % 60
    return f"{hours:02}:{minutes:02}:{seconds:02}"

def get_clean_article_content(url):
    """Devuelve el texto del artículo o None si hubo cualquier error."""
    try:
        headers = {"User-Agent": "Mozilla/5.0"}
        resp = requests.get(url, headers=headers, timeout=10)
        if resp.status_code != 200:
            return None
        soup = BeautifulSoup(resp.text, 'html.parser')
        for tag in ["script", "style", "aside", "nav", "footer", "header", "form", "button"]:
            for el in soup.find_all(tag):
                el.decompose()
        paragraphs = [p.get_text().strip() for p in soup.find_all("p")]
        article = "\n".join([t for t in paragraphs if t])
        # descartamos artículos demasiado cortos
        if len(article) < 100:
            return None
        return article
    except Exception:
        return None

def scrape_article_contents(df, url_column="urls", content_column="article_contents", delay=2):
    print(f"🔎 Starting article scraping for {len(df)} days...")
    start_time = datetime.now()

    for index, row in df.iterrows():
        date_info = row.get("date", f"index {index}")
        print(f"\n📆 Scraping articles for {date_info}...")

        article_texts = []
        urls = row.get(url_column, [])

        if not isinstance(urls, list) or not urls:
            print(f"⚠️ No valid URLs to scrape for {date_info}. Skipping.")
            df.at[index, content_column] = []
            continue

        total_urls = len(urls)
        for i, url in enumerate(urls, 1):
            print(f"🔍 Scraping URL {i}/{total_urls} for {date_info}")
            try:
                content = get_clean_article_content(url)
                article_texts.append(content)
            except Exception as e:
                article_texts.append(f"❌ Error scraping {url}: {str(e)}")
            time.sleep(delay)

        df.at[index, content_column] = article_texts

    end_time = datetime.now()
    duration = end_time - start_time
    print(f"\n✅ Finished scraping. Duration: {format_duration(duration)}")
    return df

from datetime import datetime, timedelta
import time
import requests
import pandas as pd

def fetch_gnews_articles(
    start_date, end_date, query,
    language="en", max_articles=10,
    sort_by="publishedAt", delay=2
):
    print("🚀 Starting GNews article collection...")
    news_data = []
    start_time = datetime.now()
    current_date = start_date

    while current_date <= end_date:
        # Skip weekends (5 = Saturday, 6 = Sunday)
        if current_date.weekday() >= 5:
            current_date += timedelta(days=1)
            continue

        formatted_date = current_date.strftime("%Y-%m-%d")
        from_date     = current_date.strftime("%Y-%m-%dT00:00:00Z")
        to_date       = current_date.strftime("%Y-%m-%dT23:59:59Z")

        print(f"📅 Fetching articles for {formatted_date}...")

        url = (
            f"https://gnews.io/api/v4/search?"
            f"q={query}&lang={language}&max={max_articles}"
            f"&sortby={sort_by}&from={from_date}&to={to_date}"
            f"&category=business,technology&apikey={GNEWS_API_KEY}"
        )
        try:
            response = requests.get(url, timeout=10)
            titles, urls, sources, descriptions = [], [], [], []

            if response.status_code == 200:
                data = response.json()
                articles = data.get("articles", [])
                if articles:
                    print(f"✅ {len(articles)} articles found for {formatted_date}")
                    for article in articles:
                        titles.append(article.get("title", ""))
                        urls.append(article.get("url", ""))
                        sources.append(article.get("source", {}).get("name", ""))
                        descriptions.append(article.get("description", ""))
                else:
                    print(f"⚠️ No articles found for {formatted_date}")
            else:
                print(f"❌ Error {response.status_code} on {formatted_date}: {response.text}")

            news_data.append({
                "date": formatted_date,
                "titles": titles,
                "urls": urls,
                "sources": sources,
                "descriptions": descriptions
            })

        except Exception as e:
            print(f"❌ Exception while fetching {formatted_date}: {e}")

        # Advance to next day
        current_date += timedelta(days=1)
        time.sleep(delay)

    end_time = datetime.now()
    print("✅ Finished article collection from GNews.")
    print(f"⏱️ Time taken: {format_duration(end_time - start_time)}")

    df = pd.DataFrame(news_data)
    df["article_contents"] = None
    return df

def fetch_thenewsapi_articles(
    start_date, end_date, query,
    language="en", max_articles=3,
    sort_by="relevance_score,published_at", delay=2
):
    print("🚀 Starting TheNewsAPI article collection...")
    news_data = []
    start_time = datetime.now()
    current_date = start_date

    while current_date <= end_date:
        # Skip weekends (5 = Saturday, 6 = Sunday)
        if current_date.weekday() >= 5:
            current_date += timedelta(days=1)
            continue

        formatted_date = current_date.strftime("%Y-%m-%d")
        print(f"📅 Fetching articles for {formatted_date}...")

        url = (
            f"https://api.thenewsapi.com/v1/news/all?"
            f"search={query}&language={language}&limit={max_articles}"
            f"&sort={sort_by}&published_on={formatted_date}"
            f"&api_token={THENEWS_API_KEY}"
        )

        titles, urls, sources, descriptions = [], [], [], []
        try:
            response = requests.get(url, timeout=10)
            if response.status_code == 200:
                data = response.json().get("data", [])
                if data:
                    print(f"✅ {len(data)} articles found for {formatted_date}")
                    for article in data:
                        titles.append(article.get("title", ""))
                        urls.append(article.get("url", ""))
                        sources.append(article.get("source", ""))
                        descriptions.append(article.get("description", ""))
                else:
                    print(f"⚠️ No articles found for {formatted_date}")
            else:
                print(f"❌ Error {response.status_code} on {formatted_date}: {response.text}")
        except Exception as e:
            print(f"❌ Exception while fetching {formatted_date}: {e}")

        news_data.append({
            "date": formatted_date,
            "titles": titles,
            "urls": urls,
            "sources": sources,
            "descriptions": descriptions
        })

        # Advance to next day
        current_date += timedelta(days=1)
        time.sleep(delay)

    end_time = datetime.now()
    print("✅ Finished article collection from TheNewsAPI.")
    print(f"⏱️ Time taken: {format_duration(end_time - start_time)}")

    df = pd.DataFrame(news_data)
    df["article_contents"] = None
    return df

def save_monthly_news(df, source_name, start_date, out_dir):
    """
    Guarda df en formato JSON-lines con nombre:
      df-{source_name}-{YYYY}_{MM}.jsonl

    Parámetros:
    - df: DataFrame con columna 'date' + listas (titles, urls, etc.)
    - source_name: p.ej. 'gnews' o 'thenewsapi'
    - start_date: datetime del primer día del mes
    - out_dir: carpeta donde guardar (se crea si no existe)
    """
    # 1) Aseguramos que el directorio existe
    os.makedirs(out_dir, exist_ok=True)

    # 2) Extraemos año/mes
    year  = start_date.year
    month = start_date.month

    # 3) Construimos nombre de fichero con source_name, no con df
    fname = f"df-{source_name}-{year}_{month:02d}.jsonl"
    path  = os.path.join(out_dir, fname)

    # 4) Guardamos
    df.to_json(
        path,
        orient="records",
        date_format="iso",
        lines=True,
        force_ascii=False
    )
    print(f"✅ Saved {len(df)} records to {path}")

# %%
# Shared config
start_date = datetime(2024, 12, 1)
end_date = datetime(2024, 12, 31)
delay_seconds = 2

# %% [markdown]
# # GNews - gnews.io

# %%
# GNews execution
query_gnews = '(Bitcoin OR BTC OR crypto OR cryptocurrency) AND (price OR market OR trading OR volatility)'
df_gnews = fetch_gnews_articles(start_date, end_date, query_gnews, delay=delay_seconds)
df_gnews = scrape_article_contents(df_gnews, delay=delay_seconds)
save_monthly_news(
    df_gnews,
    source_name="gnews",
    start_date=start_date,
    out_dir="gnews_data"
)
# Out:
# 🚀 Starting GNews article collection...
# 📅 Fetching articles for 2024-12-02...
# ✅ 10 articles found for 2024-12-02
# 📅 Fetching articles for 2024-12-03...
# ✅ 6 articles found for 2024-12-03
# 📅 Fetching articles for 2024-12-04...
# ✅ 10 articles found for 2024-12-04
# 📅 Fetching articles for 2024-12-05...
# ✅ 10 articles found for 2024-12-05
# 📅 Fetching articles for 2024-12-06...
# ✅ 10 articles found for 2024-12-06
# 📅 Fetching articles for 2024-12-09...
# ✅ 5 articles found for 2024-12-09
# 📅 Fetching articles for 2024-12-10...
# ✅ 9 articles found for 2024-12-10
# 📅 Fetching articles for 2024-12-11...
# ✅ 8 articles found for 2024-12-11
# 📅 Fetching articles for 2024-12-12...
# ✅ 4 articles found for 2024-12-12
# 📅 Fetching articles for 2024-12-13...
# ✅ 6 articles found for 2024-12-13
# 📅 Fetching articles for 2024-12-16...
# ✅ 10 articles found for 2024-12-16
# 📅 Fetching articles for 2024-12-17...
# ✅ 3 articles found for 2024-12-17
# 📅 Fetching articles for 2024-12-18...
# ✅ 7 articles found for 2024-12-18
# 📅 Fetching articles for 2024-12-19...
# ✅ 6 articles found for 2024-12-19
# 📅 Fetching articles for 2024-12-20...
# ✅ 7 articles found for 2024-12-20
# 📅 Fetching articles for 2024-12-23...
# ✅ 4 articles found for 2024-12-23
# 📅 Fetching articles for 2024-12-24...
# ✅ 4 articles found for 2024-12-24
# 📅 Fetching articles for 2024-12-25...
# ⚠️ No articles found for 2024-12-25
# 📅 Fetching articles for 2024-12-26...
# ✅ 8 articles found for 2024-12-26
# 📅 Fetching articles for 2024-12-27...
# ✅ 4 articles found for 2024-12-27
# 📅 Fetching articles for 2024-12-30...
# ✅ 4 articles found for 2024-12-30
# 📅 Fetching articles for 2024-12-31...
# ✅ 10 articles found for 2024-12-31
# ✅ Finished article collection from GNews.
# ⏱️ Time taken: 00:01:07
# 🔎 Starting article scraping for 22 days...
#
# 📆 Scraping articles for 2024-12-02...
# 🔍 Scraping URL 1/10 for 2024-12-02
# 🔍 Scraping URL 2/10 for 2024-12-02
# 🔍 Scraping URL 3/10 for 2024-12-02
# 🔍 Scraping URL 4/10 for 2024-12-02
# 🔍 Scraping URL 5/10 for 2024-12-02
# 🔍 Scraping URL 6/10 for 2024-12-02
# 🔍 Scraping URL 7/10 for 2024-12-02
# 🔍 Scraping URL 8/10 for 2024-12-02
# 🔍 Scraping URL 9/10 for 2024-12-02
# 🔍 Scraping URL 10/10 for 2024-12-02
#
# 📆 Scraping articles for 2024-12-03...
# 🔍 Scraping URL 1/6 for 2024-12-03
# 🔍 Scraping URL 2/6 for 2024-12-03
# 🔍 Scraping URL 3/6 for 2024-12-03
# 🔍 Scraping URL 4/6 for 2024-12-03
# 🔍 Scraping URL 5/6 for 2024-12-03
# 🔍 Scraping URL 6/6 for 2024-12-03
#
# 📆 Scraping articles for 2024-12-04...
# 🔍 Scraping URL 1/10 for 2024-12-04
# 🔍 Scraping URL 2/10 for 2024-12-04
# 🔍 Scraping URL 3/10 for 2024-12-04
# 🔍 Scraping URL 4/10 for 2024-12-04
# 🔍 Scraping URL 5/10 for 2024-12-04
# 🔍 Scraping URL 6/10 for 2024-12-04
# 🔍 Scraping URL 7/10 for 2024-12-04
# 🔍 Scraping URL 8/10 for 2024-12-04
# 🔍 Scraping URL 9/10 for 2024-12-04
# 🔍 Scraping URL 10/10 for 2024-12-04
#
# 📆 Scraping articles for 2024-12-05...
# 🔍 Scraping URL 1/10 for 2024-12-05
# 🔍 Scraping URL 2/10 for 2024-12-05
# 🔍 Scraping URL 3/10 for 2024-12-05
# 🔍 Scraping URL 4/10 for 2024-12-05
# 🔍 Scraping URL 5/10 for 2024-12-05
# 🔍 Scraping URL 6/10 for 2024-12-05
# 🔍 Scraping URL 7/10 for 2024-12-05
# 🔍 Scraping URL 8/10 for 2024-12-05
# 🔍 Scraping URL 9/10 for 2024-12-05
# 🔍 Scraping URL 10/10 for 2024-12-05
#
# 📆 Scraping articles for 2024-12-06...
# 🔍 Scraping URL 1/10 for 2024-12-06
# 🔍 Scraping URL 2/10 for 2024-12-06
# 🔍 Scraping URL 3/10 for 2024-12-06
# 🔍 Scraping URL 4/10 for 2024-12-06
# 🔍 Scraping URL 5/10 for 2024-12-06
# 🔍 Scraping URL 6/10 for 2024-12-06
# 🔍 Scraping URL 7/10 for 2024-12-06
# 🔍 Scraping URL 8/10 for 2024-12-06
# 🔍 Scraping URL 9/10 for 2024-12-06
# 🔍 Scraping URL 10/10 for 2024-12-06
#
# 📆 Scraping articles for 2024-12-09...
# 🔍 Scraping URL 1/5 for 2024-12-09
# 🔍 Scraping URL 2/5 for 2024-12-09
# 🔍 Scraping URL 3/5 for 2024-12-09
# 🔍 Scraping URL 4/5 for 2024-12-09
# 🔍 Scraping URL 5/5 for 2024-12-09
#
# 📆 Scraping articles for 2024-12-10...
# 🔍 Scraping URL 1/9 for 2024-12-10
# 🔍 Scraping URL 2/9 for 2024-12-10
# 🔍 Scraping URL 3/9 for 2024-12-10
# 🔍 Scraping URL 4/9 for 2024-12-10
# 🔍 Scraping URL 5/9 for 2024-12-10
# 🔍 Scraping URL 6/9 for 2024-12-10
# 🔍 Scraping URL 7/9 for 2024-12-10
# 🔍 Scraping URL 8/9 for 2024-12-10
# 🔍 Scraping URL 9/9 for 2024-12-10
#
# 📆 Scraping articles for 2024-12-11...
# 🔍 Scraping URL 1/8 for 2024-12-11
# 🔍 Scraping URL 2/8 for 2024-12-11
# 🔍 Scraping URL 3/8 for 2024-12-11
# 🔍 Scraping URL 4/8 for 2024-12-11
# 🔍 Scraping URL 5/8 for 2024-12-11
# 🔍 Scraping URL 6/8 for 2024-12-11
# 🔍 Scraping URL 7/8 for 2024-12-11
# 🔍 Scraping URL 8/8 for 2024-12-11
#
# 📆 Scraping articles for 2024-12-12...
# 🔍 Scraping URL 1/4 for 2024-12-12
# 🔍 Scraping URL 2/4 for 2024-12-12
# 🔍 Scraping URL 3/4 for 2024-12-12
# 🔍 Scraping URL 4/4 for 2024-12-12
#
# 📆 Scraping articles for 2024-12-13...
# 🔍 Scraping URL 1/6 for 2024-12-13
# 🔍 Scraping URL 2/6 for 2024-12-13
# 🔍 Scraping URL 3/6 for 2024-12-13
# 🔍 Scraping URL 4/6 for 2024-12-13
# 🔍 Scraping URL 5/6 for 2024-12-13
# 🔍 Scraping URL 6/6 for 2024-12-13
#
# 📆 Scraping articles for 2024-12-16...
# 🔍 Scraping URL 1/10 for 2024-12-16
# 🔍 Scraping URL 2/10 for 2024-12-16
# 🔍 Scraping URL 3/10 for 2024-12-16
# 🔍 Scraping URL 4/10 for 2024-12-16
# 🔍 Scraping URL 5/10 for 2024-12-16
# 🔍 Scraping URL 6/10 for 2024-12-16
# 🔍 Scraping URL 7/10 for 2024-12-16
# 🔍 Scraping URL 8/10 for 2024-12-16
# 🔍 Scraping URL 9/10 for 2024-12-16
# 🔍 Scraping URL 10/10 for 2024-12-16
#
# 📆 Scraping articles for 2024-12-17...
# 🔍 Scraping URL 1/3 for 2024-12-17
# 🔍 Scraping URL 2/3 for 2024-12-17
# 🔍 Scraping URL 3/3 for 2024-12-17
#
# 📆 Scraping articles for 2024-12-18...
# 🔍 Scraping URL 1/7 for 2024-12-18
# 🔍 Scraping URL 2/7 for 2024-12-18
# 🔍 Scraping URL 3/7 for 2024-12-18
# 🔍 Scraping URL 4/7 for 2024-12-18
# 🔍 Scraping URL 5/7 for 2024-12-18
# 🔍 Scraping URL 6/7 for 2024-12-18
# 🔍 Scraping URL 7/7 for 2024-12-18
#
# 📆 Scraping articles for 2024-12-19...
# 🔍 Scraping URL 1/6 for 2024-12-19
# 🔍 Scraping URL 2/6 for 2024-12-19
# 🔍 Scraping URL 3/6 for 2024-12-19
# 🔍 Scraping URL 4/6 for 2024-12-19
# 🔍 Scraping URL 5/6 for 2024-12-19
# 🔍 Scraping URL 6/6 for 2024-12-19
#
# 📆 Scraping articles for 2024-12-20...
# 🔍 Scraping URL 1/7 for 2024-12-20
# 🔍 Scraping URL 2/7 for 2024-12-20
# 🔍 Scraping URL 3/7 for 2024-12-20
# 🔍 Scraping URL 4/7 for 2024-12-20
# 🔍 Scraping URL 5/7 for 2024-12-20
# 🔍 Scraping URL 6/7 for 2024-12-20
# 🔍 Scraping URL 7/7 for 2024-12-20
#
# 📆 Scraping articles for 2024-12-23...
# 🔍 Scraping URL 1/4 for 2024-12-23
# 🔍 Scraping URL 2/4 for 2024-12-23
# 🔍 Scraping URL 3/4 for 2024-12-23
# 🔍 Scraping URL 4/4 for 2024-12-23
#
# 📆 Scraping articles for 2024-12-24...
# 🔍 Scraping URL 1/4 for 2024-12-24
# 🔍 Scraping URL 2/4 for 2024-12-24
# 🔍 Scraping URL 3/4 for 2024-12-24
# 🔍 Scraping URL 4/4 for 2024-12-24
#
# 📆 Scraping articles for 2024-12-25...
# ⚠️ No valid URLs to scrape for 2024-12-25. Skipping.
#
# 📆 Scraping articles for 2024-12-26...
# 🔍 Scraping URL 1/8 for 2024-12-26
# 🔍 Scraping URL 2/8 for 2024-12-26
# 🔍 Scraping URL 3/8 for 2024-12-26
# 🔍 Scraping URL 4/8 for 2024-12-26
# 🔍 Scraping URL 5/8 for 2024-12-26
# 🔍 Scraping URL 6/8 for 2024-12-26
# 🔍 Scraping URL 7/8 for 2024-12-26
# 🔍 Scraping URL 8/8 for 2024-12-26
#
# 📆 Scraping articles for 2024-12-27...
# 🔍 Scraping URL 1/4 for 2024-12-27
# 🔍 Scraping URL 2/4 for 2024-12-27
# 🔍 Scraping URL 3/4 for 2024-12-27
# 🔍 Scraping URL 4/4 for 2024-12-27
#
# 📆 Scraping articles for 2024-12-30...
# 🔍 Scraping URL 1/4 for 2024-12-30
# 🔍 Scraping URL 2/4 for 2024-12-30
# 🔍 Scraping URL 3/4 for 2024-12-30
# 🔍 Scraping URL 4/4 for 2024-12-30
#
# 📆 Scraping articles for 2024-12-31...
# 🔍 Scraping URL 1/10 for 2024-12-31
# 🔍 Scraping URL 2/10 for 2024-12-31
# 🔍 Scraping URL 3/10 for 2024-12-31
# 🔍 Scraping URL 4/10 for 2024-12-31
# 🔍 Scraping URL 5/10 for 2024-12-31
# 🔍 Scraping URL 6/10 for 2024-12-31
# 🔍 Scraping URL 7/10 for 2024-12-31
# 🔍 Scraping URL 8/10 for 2024-12-31
# 🔍 Scraping URL 9/10 for 2024-12-31
# 🔍 Scraping URL 10/10 for 2024-12-31
#
# ✅ Finished scraping. Duration: 00:12:01
# ✅ Saved 22 records to gnews_data\df-gnews-2024_12.jsonl

# %% [markdown]
# # TheNewsAPI - thenewsapi.com

# %%
# TheNewsAPI execution
query_thenews = '(Bitcoin OR BTC OR crypto OR cryptocurrency) AND (price OR market OR trading OR volatility)'
df_thenews = fetch_thenewsapi_articles(start_date, end_date, query_thenews, delay=delay_seconds)
df_thenews = scrape_article_contents(df_thenews, delay=delay_seconds)
save_monthly_news(
    df_thenews,
    source_name="thenews",
    start_date=start_date,
    out_dir="thenewsapi_data"
)
# Out:
# 🚀 Starting TheNewsAPI article collection...
# 📅 Fetching articles for 2024-12-02...
# ✅ 1 articles found for 2024-12-02
# 📅 Fetching articles for 2024-12-03...
# ✅ 3 articles found for 2024-12-03
# 📅 Fetching articles for 2024-12-04...
# ✅ 1 articles found for 2024-12-04
# 📅 Fetching articles for 2024-12-05...
# ✅ 3 articles found for 2024-12-05
# 📅 Fetching articles for 2024-12-06...
# ✅ 1 articles found for 2024-12-06
# 📅 Fetching articles for 2024-12-09...
# ✅ 3 articles found for 2024-12-09
# 📅 Fetching articles for 2024-12-10...
# ✅ 1 articles found for 2024-12-10
# 📅 Fetching articles for 2024-12-11...
# ✅ 2 articles found for 2024-12-11
# 📅 Fetching articles for 2024-12-12...
# ✅ 2 articles found for 2024-12-12
# 📅 Fetching articles for 2024-12-13...
# ✅ 3 articles found for 2024-12-13
# 📅 Fetching articles for 2024-12-16...
# ✅ 3 articles found for 2024-12-16
# 📅 Fetching articles for 2024-12-17...
# ✅ 3 articles found for 2024-12-17
# 📅 Fetching articles for 2024-12-18...
# ✅ 3 articles found for 2024-12-18
# 📅 Fetching articles for 2024-12-19...
# ⚠️ No articles found for 2024-12-19
# 📅 Fetching articles for 2024-12-20...
# ✅ 3 articles found for 2024-12-20
# 📅 Fetching articles for 2024-12-23...
# ✅ 3 articles found for 2024-12-23
# 📅 Fetching articles for 2024-12-24...
# ✅ 2 articles found for 2024-12-24
# 📅 Fetching articles for 2024-12-25...
# ✅ 3 articles found for 2024-12-25
# 📅 Fetching articles for 2024-12-26...
# ✅ 2 articles found for 2024-12-26
# 📅 Fetching articles for 2024-12-27...
# ✅ 2 articles found for 2024-12-27
# 📅 Fetching articles for 2024-12-30...
# ✅ 2 articles found for 2024-12-30
# 📅 Fetching articles for 2024-12-31...
# ✅ 3 articles found for 2024-12-31
# ✅ Finished article collection from TheNewsAPI.
# ⏱️ Time taken: 00:01:15
# 🔎 Starting article scraping for 22 days...
#
# 📆 Scraping articles for 2024-12-02...
# 🔍 Scraping URL 1/1 for 2024-12-02
#
# 📆 Scraping articles for 2024-12-03...
# 🔍 Scraping URL 1/3 for 2024-12-03
# 🔍 Scraping URL 2/3 for 2024-12-03
# 🔍 Scraping URL 3/3 for 2024-12-03
#
# 📆 Scraping articles for 2024-12-04...
# 🔍 Scraping URL 1/1 for 2024-12-04
#
# 📆 Scraping articles for 2024-12-05...
# 🔍 Scraping URL 1/3 for 2024-12-05
# 🔍 Scraping URL 2/3 for 2024-12-05
# 🔍 Scraping URL 3/3 for 2024-12-05
#
# 📆 Scraping articles for 2024-12-06...
# 🔍 Scraping URL 1/1 for 2024-12-06
#
# 📆 Scraping articles for 2024-12-09...
# 🔍 Scraping URL 1/3 for 2024-12-09
# 🔍 Scraping URL 2/3 for 2024-12-09
# 🔍 Scraping URL 3/3 for 2024-12-09
#
# 📆 Scraping articles for 2024-12-10...
# 🔍 Scraping URL 1/1 for 2024-12-10
#
# 📆 Scraping articles for 2024-12-11...
# 🔍 Scraping URL 1/2 for 2024-12-11
# 🔍 Scraping URL 2/2 for 2024-12-11
#
# 📆 Scraping articles for 2024-12-12...
# 🔍 Scraping URL 1/2 for 2024-12-12
# 🔍 Scraping URL 2/2 for 2024-12-12
#
# 📆 Scraping articles for 2024-12-13...
# 🔍 Scraping URL 1/3 for 2024-12-13
# 🔍 Scraping URL 2/3 for 2024-12-13
# 🔍 Scraping URL 3/3 for 2024-12-13
#
# 📆 Scraping articles for 2024-12-16...
# 🔍 Scraping URL 1/3 for 2024-12-16
# 🔍 Scraping URL 2/3 for 2024-12-16
# 🔍 Scraping URL 3/3 for 2024-12-16
#
# 📆 Scraping articles for 2024-12-17...
# 🔍 Scraping URL 1/3 for 2024-12-17
# 🔍 Scraping URL 2/3 for 2024-12-17
# 🔍 Scraping URL 3/3 for 2024-12-17
#
# 📆 Scraping articles for 2024-12-18...
# 🔍 Scraping URL 1/3 for 2024-12-18
# 🔍 Scraping URL 2/3 for 2024-12-18
# 🔍 Scraping URL 3/3 for 2024-12-18
#
# 📆 Scraping articles for 2024-12-19...
# ⚠️ No valid URLs to scrape for 2024-12-19. Skipping.
#
# 📆 Scraping articles for 2024-12-20...
# 🔍 Scraping URL 1/3 for 2024-12-20
# 🔍 Scraping URL 2/3 for 2024-12-20
# 🔍 Scraping URL 3/3 for 2024-12-20
#
# 📆 Scraping articles for 2024-12-23...
# 🔍 Scraping URL 1/3 for 2024-12-23
# 🔍 Scraping URL 2/3 for 2024-12-23
# 🔍 Scraping URL 3/3 for 2024-12-23
#
# 📆 Scraping articles for 2024-12-24...
# 🔍 Scraping URL 1/2 for 2024-12-24
# 🔍 Scraping URL 2/2 for 2024-12-24
#
# 📆 Scraping articles for 2024-12-25...
# 🔍 Scraping URL 1/3 for 2024-12-25
# 🔍 Scraping URL 2/3 for 2024-12-25
# 🔍 Scraping URL 3/3 for 2024-12-25
#
# 📆 Scraping articles for 2024-12-26...
# 🔍 Scraping URL 1/2 for 2024-12-26
# 🔍 Scraping URL 2/2 for 2024-12-26
#
# 📆 Scraping articles for 2024-12-27...
# 🔍 Scraping URL 1/2 for 2024-12-27
# 🔍 Scraping URL 2/2 for 2024-12-27
#
# 📆 Scraping articles for 2024-12-30...
# 🔍 Scraping URL 1/2 for 2024-12-30
# 🔍 Scraping URL 2/2 for 2024-12-30
#
# 📆 Scraping articles for 2024-12-31...
# 🔍 Scraping URL 1/3 for 2024-12-31
# 🔍 Scraping URL 2/3 for 2024-12-31
# 🔍 Scraping URL 3/3 for 2024-12-31
#
# ✅ Finished scraping. Duration: 00:03:12
# ✅ Saved 22 records to thenewsapi_data\df-thenews-2024_12.jsonl

# %% [markdown]
# ### join

# %%
import glob
import pandas as pd
from transformers import pipeline

# %%
def load_api_news(pattern):
    files = sorted(glob.glob(pattern))
    dfs = [pd.read_json(f, orient="records", lines=True) for f in files]
    df = pd.concat(dfs, ignore_index=True)
    df["date"] = pd.to_datetime(df["date"])
    return df.set_index("date")

# %%
df_gnews = load_api_news("gnews_data/*.jsonl")
df_thenews = load_api_news("thenewsapi_data/*.jsonl")

# %%
df_news = df_gnews.join(
    df_thenews,
    how="outer",
    lsuffix="_gnews",
    rsuffix="_thenews"
)

# %%
cols = ["titles","urls","sources","descriptions","article_contents"]
for col in cols:
    gcol = f"{col}_gnews"
    tcol = f"{col}_thenews"
    df_news[col] = (
        df_news[gcol].apply(lambda x: x or []) +
        df_news[tcol].apply(lambda x: x or [])
    )

# %%
df_news = df_news.drop(columns=[f"{c}_gnews" for c in cols] + [f"{c}_thenews" for c in cols])

# %%
df_news
# Out:
#                                                        titles  \
# date
# 2024-01-01  [Bitcoin price surges above $45,000 for first ...
# 2024-01-02  [The hullabaloo over crypto has quietened desp...
# 2024-01-03  [Biggest stock movers today: Crypto stocks, So...
# 2024-01-04  [Bitcoin price in Saudi Arabia on January 4, 2...
# 2024-01-05  [Elon Musk drops price of X gold checks amid r...
# ...                                                       ...
# 2024-12-25  [AMBCrypto Report: December 2024 Crypto Roundu...
# 2024-12-26  [Dow ekes out gains, bitcoin slumps as 'Santa ...
# 2024-12-27  [Crypto's tailwinds in 2025 could push bitcoin...
# 2024-12-30  [Bitcoin is ending 2024 on a losing streak. He...
# 2024-12-31  [U.S. News Round-Up: Election Interference, Po...
#
#                                                          urls  \
# date
# 2024-01-01  [https://www.livemint.com/market/cryptocurrenc...
# 2024-01-02  [https://www.livemint.com/opinion/online-views...
# 2024-01-03  [https://seekingalpha.com/news/4051785-biggest...
# 2024-01-04  [https://www.bolnews.com/business/2024/01/btc-...
# 2024-01-05  [https://arstechnica.com/tech-policy/2024/01/c...
# ...                                                       ...
# 2024-12-25  [https://ambcrypto.com/ambcrypto-report-decemb...
# 2024-12-26  [https://finance.yahoo.com/news/live/stock-mar...
# 2024-12-27  [https://www.cnbc.com/2024/12/27/cryptos-tailw...
# 2024-12-30  [https://finance.yahoo.com/news/bitcoin-ending...
# 2024-12-31  [https://www.devdiscourse.com/article/law-orde...
#
#                                                       sources  \
# date
# 2024-01-01                                   [Livemint, CNBC]
# 2024-01-02  [Livemint, Hot Hardware, CNBC, Business Inside...
# 2024-01-03      [Seeking Alpha, investing.com, investing.com]
# 2024-01-04  [BOL News, Yahoo Finance, Motley Fool Australi...
# 2024-01-05  [Ars Technica, Investing.com, Investing.com, i...
# ...                                                       ...
# 2024-12-25            [ambcrypto.com, medium.com, medium.com]
# 2024-12-26  [Yahoo Finance, Yahoo Canada Finance, Yahoo Fi...
# 2024-12-27  [CNBC, Yahoo Finance, BOL News, BOL News, yaho...
# 2024-12-30  [Yahoo Finance, Yahoo Finance, ThePrint, Devdi...
# 2024-12-31  [Devdiscourse, Yahoo Finance, The Guardian, CN...
#
#                                                  descriptions  \
# date
# 2024-01-01  [Bitcoin price surged on expectation that the ...
# 2024-01-02  [Bitcoin’s price shot up in 2023 but few seeme...
# 2024-01-03  [Stock futures inched lower in the early tradi...
# 2024-01-04  [As of January 04, 2024, the Bitcoin market in...
# 2024-01-05  [Reports come the same week X reduced the cost...
# ...                                                       ...
# 2024-12-25  [Explore December's crypto highlights: Bitcoin...
# 2024-12-26  [US stocks were set to open post-Christmas tra...
# 2024-12-27  [Investors in cryptocurrencies are eager for t...
# 2024-12-30  [Historical Bitcoin and market data says 2025 ...
# 2024-12-31  [The U.S. has imposed sanctions on Iranian and...
#
#                                              article_contents
# date
# 2024-01-01  [Bitcoin price surged over 6% to break above $...
# 2024-01-02  [This is a Mint Premium article gifted to you....
# 2024-01-03                                 [None, None, None]
# 2024-01-04  [04th Jan, 2024. 07:22 pm\nShare\nListen\nFont...
# 2024-01-05  [There's currently a surge in cryptocurrency a...
# ...                                                       ...
# 2024-12-25  [Listed below are the key takeaways for the mo...
# 2024-12-26  [Oops, something went wrong\nUnlock stock pick...
# 2024-12-27  [None, Oops, something went wrong\nUnlock stoc...
# 2024-12-30  [Oops, something went wrong\nUnlock stock pick...
# 2024-12-31  [The United States has announced sanctions aga...
#
# [262 rows x 5 columns]

# %%
from transformers import AutoModelForSequenceClassification, AutoTokenizer, AutoConfig
from scipy.special import softmax
import torch
import pandas as pd

MODEL = "cardiffnlp/twitter-roberta-base-sentiment-latest"
tokenizer = AutoTokenizer.from_pretrained(MODEL)
config = AutoConfig.from_pretrained(MODEL)
model = AutoModelForSequenceClassification.from_pretrained(MODEL)
# Out:
# Some weights of the model checkpoint at cardiffnlp/twitter-roberta-base-sentiment-latest were not used when initializing RobertaForSequenceClassification: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
def get_sentiment_score(text):
    if not isinstance(text, str) or not text.strip():
        return None  # o 0, según tu preferencia
    encoded_input = tokenizer(text, return_tensors='pt', truncation=True, max_length=512)
    with torch.no_grad():
        output = model(**encoded_input)
    scores = output[0][0].detach().numpy()
    scores = softmax(scores)
    sentiment = (-1 * scores[0]) + (0 * scores[1]) + (1 * scores[2])
    return sentiment

# %%
def mean_sentiment(article_list):
    if not isinstance(article_list, list) or not article_list:
        return None  # o 0, según tu preferencia
    scores = [get_sentiment_score(article) for article in article_list if isinstance(article, str) and article.strip()]
    if not scores:
        return None  # o 0, según tu preferencia
    return sum(scores) / len(scores)

# %%
df_news["mean_sentiment"] = df_news["article_contents"].apply(mean_sentiment)

# %%
df_news.head()
# Out:
#                                                        titles  \
# date
# 2024-01-01  [Bitcoin price surges above $45,000 for first ...
# 2024-01-02  [The hullabaloo over crypto has quietened desp...
# 2024-01-03  [Biggest stock movers today: Crypto stocks, So...
# 2024-01-04  [Bitcoin price in Saudi Arabia on January 4, 2...
# 2024-01-05  [Elon Musk drops price of X gold checks amid r...
#
#                                                          urls  \
# date
# 2024-01-01  [https://www.livemint.com/market/cryptocurrenc...
# 2024-01-02  [https://www.livemint.com/opinion/online-views...
# 2024-01-03  [https://seekingalpha.com/news/4051785-biggest...
# 2024-01-04  [https://www.bolnews.com/business/2024/01/btc-...
# 2024-01-05  [https://arstechnica.com/tech-policy/2024/01/c...
#
#                                                       sources  \
# date
# 2024-01-01                                   [Livemint, CNBC]
# 2024-01-02  [Livemint, Hot Hardware, CNBC, Business Inside...
# 2024-01-03      [Seeking Alpha, investing.com, investing.com]
# 2024-01-04  [BOL News, Yahoo Finance, Motley Fool Australi...
# 2024-01-05  [Ars Technica, Investing.com, Investing.com, i...
#
#                                                  descriptions  \
# date
# 2024-01-01  [Bitcoin price surged on expectation that the ...
# 2024-01-02  [Bitcoin’s price shot up in 2023 but few seeme...
# 2024-01-03  [Stock futures inched lower in the early tradi...
# 2024-01-04  [As of January 04, 2024, the Bitcoin market in...
# 2024-01-05  [Reports come the same week X reduced the cost...
#
#                                              article_contents  mean_sentiment
# date
# 2024-01-01  [Bitcoin price surged over 6% to break above $...        0.599507
# 2024-01-02  [This is a Mint Premium article gifted to you....        0.302295
# 2024-01-03                                 [None, None, None]             NaN
# 2024-01-04  [04th Jan, 2024. 07:22 pm\nShare\nListen\nFont...        0.165357
# 2024-01-05  [There's currently a surge in cryptocurrency a...       -0.506613

# %%
df_news.to_parquet('df_news_sentiment.parquet')

# %%
print(df_news['mean_sentiment'].describe())
# Out:
# count    250.000000
# mean       0.118155
# std        0.239777
# min       -0.544396
# 25%       -0.011591
# 50%        0.094924
# 75%        0.276930
# max        0.918095
# Name: mean_sentiment, dtype: float64

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))
df_news['mean_sentiment'].hist(bins=20, edgecolor='black')
plt.title('Distribución de Mean Sentiment')
plt.xlabel('Mean Sentiment')
plt.ylabel('Número de días')
plt.show()

# %% [markdown]
# gráfico de barras a lo largo del tiempo!!!!! añadir
