# %% [markdown]
# # 📊 Comparativa de APIs de Noticias
#
# | API             | Límite Gratuito             | Cobertura                  | Datos Proporcionados                                     | Análisis de Sentimiento | Ordenación Disponible            | Idiomas |
# |----------------|----------------------------|----------------------------|----------------------------------------------------------|--------------------------|----------------------------------|---------|
# | **GNews.io**   | 100 solicitudes/día, 10 artículos máx. por solicitud | Noticias generales y tecnológicas | Título, URL, fuente, descripción, imagen                 | ❌ No                     | Relevancia, Fecha                | ✅ Sí |
# | **TheNewsAPI** | 100 solicitudes/día, 3 artículos máx. por solicitud  | Noticias generales            | Título, URL, fuente, resumen                             | ❌ No                     | Relevancia, Fecha                | ✅ Sí |
# | **Finlight.me**| 10,000 solicitudes/mes      | Noticias financieras        | Título, URL, fuente, contenido completo, sentimiento     | ✅ Sí (Positivo, Neutro, Negativo) | Fecha                            | ✅ Sí |

# %%
from datetime import datetime, timedelta
import time
import requests
import pandas as pd
from bs4 import BeautifulSoup
from finlight_client import FinlightApi

# %%
# API Keys
GNEWS_API_KEY = "087e2241d8a55daf522083c0ddab7547"
THENEWS_API_KEY = "PBqwcAoCbsLtDB2FF8NQNxpjOEeGQSkzu4tGB79E"
FINLIGHT_API_KEY = "sk_8a42ac974da4a14f105666978a59334188bf1bd406626e8fd3ef0fe0de46f771"

# %%
# Utility functions
def format_duration(td):
    total_seconds = int(td.total_seconds())
    hours = total_seconds // 3600
    minutes = (total_seconds % 3600) // 60
    seconds = total_seconds % 60
    return f"{hours:02}:{minutes:02}:{seconds:02}"

def get_clean_article_content(url):
    try:
        headers = {"User-Agent": "Mozilla/5.0"}
        response = requests.get(url, headers=headers, timeout=10)
        if response.status_code == 200:
            soup = BeautifulSoup(response.text, 'html.parser')
            for tag in ["script", "style", "aside", "nav", "footer", "header", "form", "button"]:
                for element in soup.find_all(tag):
                    element.decompose()
            paragraphs = soup.find_all("p")
            article_text = "\n".join([p.get_text().strip() for p in paragraphs if p.get_text().strip()])
            return article_text if len(article_text) > 100 else "⚠️ Article too short or not relevant"
        else:
            return f"❌ Error {response.status_code}"
    except Exception as e:
        return f"❌ Exception: {str(e)}"

def scrape_article_contents(df, url_column="urls", content_column="article_contents", delay=2):
    print(f"🔎 Starting article scraping for {len(df)} days...")
    start_time = datetime.now()

    for index, row in df.iterrows():
        date_info = row.get("date", f"index {index}")
        print(f"\n📆 Scraping articles for {date_info}...")

        article_texts = []
        urls = row.get(url_column, [])

        if not isinstance(urls, list) or not urls:
            print(f"⚠️ No valid URLs to scrape for {date_info}. Skipping.")
            df.at[index, content_column] = []
            continue

        total_urls = len(urls)
        for i, url in enumerate(urls, 1):
            print(f"🔍 Scraping URL {i}/{total_urls} for {date_info}")
            try:
                content = get_clean_article_content(url)
                article_texts.append(content)
            except Exception as e:
                article_texts.append(f"❌ Error scraping {url}: {str(e)}")
            time.sleep(delay)

        df.at[index, content_column] = article_texts

    end_time = datetime.now()
    duration = end_time - start_time
    print(f"\n✅ Finished scraping. Duration: {format_duration(duration)}")
    return df

def fetch_gnews_articles(start_date, end_date, query, language="en", max_articles=10, sort_by="publishedAt", delay=2):
    print("🚀 Starting GNews article collection...")
    news_data = []
    start_time = datetime.now()

    current_date = start_date
    while current_date <= end_date:
        formatted_date = current_date.strftime("%Y-%m-%d")
        from_date = current_date.strftime("%Y-%m-%dT00:00:00Z")
        to_date = current_date.strftime("%Y-%m-%dT23:59:59Z")

        print(f"📅 Fetching articles for {formatted_date}...")

        url = f"https://gnews.io/api/v4/search?q={query}&lang={language}&max={max_articles}&sortby={sort_by}&from={from_date}&to={to_date}&category=business,technology&apikey={GNEWS_API_KEY}"
        try:
            response = requests.get(url)
            titles, urls, sources, descriptions = [], [], [], []

            if response.status_code == 200:
                data = response.json()
                if "articles" in data and data["articles"]:
                    print(f"✅ {len(data['articles'])} articles found for {formatted_date}")
                    for article in data["articles"]:
                        titles.append(article["title"])
                        urls.append(article["url"])
                        sources.append(article["source"]["name"])
                        descriptions.append(article["description"])
                else:
                    print(f"⚠️ No articles found for {formatted_date}")
            else:
                print(f"❌ Error {response.status_code} on {formatted_date}: {response.text}")

            news_data.append({
                "date": formatted_date,
                "titles": titles,
                "urls": urls,
                "sources": sources,
                "descriptions": descriptions
            })

        except Exception as e:
            print(f"❌ Exception while fetching {formatted_date}: {str(e)}")

        current_date += timedelta(days=1)
        time.sleep(delay)

    end_time = datetime.now()
    print("✅ Finished article collection from GNews.")
    print(f"⏱️ Time taken for API article fetching: {format_duration(end_time - start_time)}")

    df = pd.DataFrame(news_data)
    df["article_contents"] = None
    return df

def fetch_thenewsapi_articles(start_date, end_date, query, language="en", max_articles=3, sort_by="relevance_score,published_at", delay=2):
    print("🚀 Starting TheNewsAPI article collection...")
    news_data = []
    start_time = datetime.now()

    current_date = start_date
    while current_date <= end_date:
        formatted_date = current_date.strftime("%Y-%m-%d")
        print(f"📅 Fetching articles for {formatted_date}...")

        url = f"https://api.thenewsapi.com/v1/news/all?search={query}&language={language}&limit={max_articles}&sort={sort_by}&published_on={formatted_date}&api_token={THENEWS_API_KEY}"
        try:
            response = requests.get(url)
            titles, urls, sources, descriptions = [], [], [], []

            if response.status_code == 200:
                data = response.json()
                if "data" in data and data["data"]:
                    print(f"✅ {len(data['data'])} articles found for {formatted_date}")
                    for article in data["data"]:
                        titles.append(article.get("title", ""))
                        urls.append(article.get("url", ""))
                        sources.append(article.get("source", ""))
                        descriptions.append(article.get("description", ""))
                else:
                    print(f"⚠️ No articles found for {formatted_date}")
            else:
                print(f"❌ Error {response.status_code} on {formatted_date}: {response.text}")

            news_data.append({
                "date": formatted_date,
                "titles": titles,
                "urls": urls,
                "sources": sources,
                "descriptions": descriptions
            })

        except Exception as e:
            print(f"❌ Exception while fetching {formatted_date}: {str(e)}")

        current_date += timedelta(days=1)
        time.sleep(delay)

    end_time = datetime.now()
    print("✅ Finished article collection from TheNewsAPI.")
    print(f"⏱️ Time taken for API article fetching: {format_duration(end_time - start_time)}")

    df = pd.DataFrame(news_data)
    df["article_contents"] = None
    return df

# %%
# Shared config
start_date = datetime(2024, 1, 1)
end_date = datetime(2024, 1, 31)
delay_seconds = 2

# %% [markdown]
# # GNews - gnews.io

# %%
# GNews execution
# 19  [Bitcoin purists are wrong to warn that the ne...
# 20  [Some of the industry representatives MintGeni...
# 21  [The Securities and Exchange Commission says a...
# 22  [Colorado securities regulators allege Pastor ...
# 23  [Buy these shares if you want to ride the rise...
# 24  [Simply being legal does not make a strategy s...
# 25  [ASX ETF provider BetaShares says 2023 was a r...
# 26  [Crypto assets were created with the explicit ...
# 27  [As of January 28, 2024, the Bitcoin market in...
# 28  [The HyperFund Ponzi scheme collapsed in 2022 ...
# 29  [The Union Budget for 2024-'25 is expected to ...
# 30  [Following Sam Bankman-Fried's guilty verdict,...
#
#                                      article_contents
# 0   [If you buy through a BGR link, we may earn an...
# 1   [❌ Error 404, Oops, something went wrong\nBitc...
# 2   [Plus: Arsenal have complained to the PGMOL ab...
# 3   [Filed under:\nLogan Paul will attempt to righ...
# 4   [There's currently a surge in cryptocurrency a...
# 5   [This is a Mint Premium article gifted to you....
# 6   [More than 8,000 people downloaded Q102 and th...
# 7   [ASX rebounds on tech rally, strong retail sal...
# 8   [NEW YORK (AP) — The Securities and Exchange C...
# 9   [In this article\nThis report is from today's ...
# 10  [Oops, something went wrong\nThere was a lot o...
# 11  [❌ Exception: HTTPSConnectionPool(host='www.de...
# 12  [Two months after shutting down its crypto wal...
# 13  [ASX closes flat as BHP offsets energy rally\n...
# 14  [DAVOS, Switzerland — For the last few years a...
# 15  [❌ Error 403, This article was published more ...
# 16  [The 66th Grammy Awards are happening Sunday i...
# 17  [Coal stocks push ASX higher as tech stocks ra...
# 18  [Federal prosecutors on Friday announced charg...
# 19  [Oops, something went wrong\nThe SEC’s recent ...
# 20  [Earlier this month, Bitcoin completed 15 year...
# 21  [The SEC says a bad actor gained control of th...
# 22  [Watch CBS News\nA Colorado pastor of an onlin...
# 23  [Image Source: Moomoo\nYou’re reading a free a...
# 24  [Exchange-traded funds (ETFs) come in many sha...
# 25  [Image source: Getty Images\nYou’re reading a ...
# 26  [The US Securities Exchange Commission (SEC) r...
# 27  [28th Jan, 2024. 06:48 pm\nShare\nListen\nFont...
# 28  [The Department of Justice on Monday announced...
# 29  [The Finance Minister's emphasis on 'Green Gro...
# 30  [Disgraced cryptocurrency exchange FTX is now ...

# %% [markdown]
# # TheNewsAPI - thenewsapi.com

# %%
# TheNewsAPI execution
query_thenews = "Bitcoin"
df_thenews = fetch_thenewsapi_articles(start_date, end_date, query_thenews, delay=delay_seconds)
df_thenews = scrape_article_contents(df_thenews, delay=delay_seconds)
# Out:
# 🚀 Starting TheNewsAPI article collection...
# 📅 Fetching articles for 2024-01-01...
# ✅ 3 articles found for 2024-01-01
# 📅 Fetching articles for 2024-01-02...
# ✅ 3 articles found for 2024-01-02
# 📅 Fetching articles for 2024-01-03...
# ✅ 3 articles found for 2024-01-03
# 📅 Fetching articles for 2024-01-04...
# ✅ 3 articles found for 2024-01-04
# 📅 Fetching articles for 2024-01-05...
# ✅ 3 articles found for 2024-01-05
# 📅 Fetching articles for 2024-01-06...
# ✅ 3 articles found for 2024-01-06
# 5           [medium.com, dailyhodl.com, benzinga.com]
# 6          [medium.com, investing.com, investing.com]
# 7   [ibtimes.com, financemagnates.com, techcentral...
# 8       [seekingalpha.com, ibtimes.com, benzinga.com]
# 9      [benzinga.com, cnbc.com, wealthmanagement.com]
# 10      [pymnts.com, marketscreener.com, ibtimes.com]
# 11  [forbes.com, finance.yahoo.com, jamaica-gleane...
# 12   [investopedia.com, seekingalpha.com, medium.com]
# 13                   [medium.com, rt.com, medium.com]
# 14    [medium.com, seekingalpha.com, bangkokpost.com]
# 15  [investopedia.com, benzinga.com, koreatimes.co...
# 16       [ft.com, investopedia.com, seekingalpha.com]
# 17        [medium.com, marketwatch.com, benzinga.com]
# 18          [investing.com, benzinga.com, forbes.com]
# 19  [moneycontrol.com, bangkokpost.com, techcentra...
# 20  [financemagnates.com, finance.yahoo.com, finan...
# 21  [morningstar.ca, finance.yahoo.com, financefee...
# 22          [seekingalpha.com, ft.com, investing.com]
# 23   [seekingalpha.com, koreatimes.co.kr, medium.com]
# 24    [bangkokpost.com, investing.com, investing.com]
# 25       [forbes.com, scoop.co.nz, morningstar.co.uk]
# 26  [finextra.com, forexlive.com, riotimesonline.com]
# 27  [investing.com, investinghaven.com, investing....
#
#                                          descriptions  \
# 0   [US crypto companies have made last-minute cha...
# 1   [Cryptocurrency News: Bitcoin surged past $45,...
# 2   [Dive into the Bitcoin $BTC Airdrop: A Distinc...
# 3   [As Spot Bitcoin ETFs loom, the market is watc...
# 4   [I’ve been hearing a lot of bearishness on Eth...
# 5   [In the world of cryptocurrencies, where innov...
# 6   [Unfortunately, finding unbiased answers to th...
# 7   [Bitcoin showed signs of recovery this week by...
# 8   [The U.S. Securities and Exchange Commission g...
# 9   [Grayscale Bitcoin Trust will become world's s...
# 10  [The Securities and Exchange Commission (SEC) ...
# 11  [On Twitter Bitcoin is the future of investing...
# 12  [Bitcoin passed its 10th anniversary in 2018 a...
# 13  [A Bitcoin airdrop is a distribution of BTC to...
# 14  [Hyperbitcoinization is a theoretical scenario...
# 15  [Investment manager VanEck is dissolving its f...
# 16  [Fade to Grayscale, BlackRock's spot bitcoin E...
# 17  [Welcome to the thrilling world of Bitcoin $BT...
# 18  [Bitcoin falls to $40,000, lowest level since ...
# 19  [The world's largest cryptocurrency was last d...
# 20  [The trustee of the now-collapsed crypto excha...
# 21  [Sometimes it’s best to just say no., To deter...
# 22  [Bitcoin has fallen below $40,000 after rising...
# 23  [DAPP is a passive product that tracks the MVI...
# 24  [Following the US Securities and Exchange Comm...
# 25  [Bitcoin has taken a pounding on the release o...
# 26  [In 2023, global crypto ownership rose by 34% ...
# 27  [Bitcoin Network Hits Historic 1 Million Miles...
#
#                                      article_contents
# 0   [US crypto companies have made last-minute cha...
# 1   [10 Most Affordable Cities in India to Buy a H...
# 2   [❌ Error 410, ❌ Error 410, ⚠️ Article too shor...
# 3   [As Spot Bitcoin ETFs loom, the market is watc...
# 4   [❌ Error 410, ❌ Error 403, ⚠️ Article too shor...
# 5   [❌ Error 410, The usual financial suspects wan...
# 6   [Sign in\nSign in\nHome\nLibrary\nStories\nSta...
# 7   [Bitcoin reclaimed the $45,000 price point on ...
# 8   [❌ Error 403, Bitcoin experienced a substantia...
# 9   [Benzinga Rankings give you vital metrics on a...
# 10  [American regulators have approved bitcoin exc...
# 11  [ByDavid G.W. Birch\nByDavid G.W. Birch\n, Con...
# 12  [Ordinarily, a 10th anniversary is a cause for...
# 13  [❌ Error 410, Bitcoin could surge to record hi...
# 14  [Sign in\nSign in\nHome\nLibrary\nStories\nSta...
# 15  [NurPhoto / Contributor / Getty Images\nInvest...
# 16  [Want a deeper look?\nThen €69 per month. Comp...
# 17  [❌ Error 410, ❌ Error 401, A JPMorgan Chase an...
# 18  [❌ Error 403, For cryptocurrency enthusiasts w...
# 19  [Discover the latest Business News, Budget 202...
# 20  [The trustee of the now-collapsed crypto excha...
# 21  [Bitcoin ETFs \nAs you probably heard, the SEC...
# 22  [❌ Error 403, Steve Johnson\nPublishedJanuary ...
# 23  [❌ Error 403, 1\nFrom 'Reply 1988' to 'When Li...
# 24  [The price of the world's most popular cryptoc...
# 25  [ByClem Chambers\nByClem Chambers\n, Senior Co...
# 26  [⚠️ Article too short or not relevant, The ter...
# 27  [❌ Error 403, Home » Crypto & Blockchain » Wha...

# %% [markdown]
# # News API - finlight.me

# %%
# Parámetros de prueba
query = "BTC"
language = "en"  # Idioma: 'en' para inglés, 'es' para español, etc.
pageSize = 20

# Inicializar el cliente de la API
client = FinlightApi(config={"api_key": FINLIGHT_API_KEY})

# Realizar la solicitud
response = client.articles.get_extended_articles(
    params={
        "query": query,
        "language": language,
        "pageSize": pageSize,
        "from": "2024-01-01",
        "to": "2024-01-31",
        "order": "DESC",
        
    }
)

# Imprimir la respuesta
response
# Out:
# {'status': 'ok', 'page': 1, 'pageSize': 20, 'articles': []}

# %%
def obtener_noticias(fecha):
    response = client.articles.get_extended_articles(
        params={
            "query": "Bitcoin OR crypto OR stocks OR finance",
            "language": "en",
            "from": fecha,
            "to": fecha,
            "order": "DESC",
            "pageSize": 50  # Tomar varias noticias por día
        }
    )
    return response.get("articles", [])

# %%
def calcular_sentimiento_promedio(noticias):
    sentimientos = []
    confianzas = []
    
    for noticia in noticias:
        sentimiento = noticia.get("sentiment", "neutral")
        confianza = float(noticia.get("confidence", 0))
        
        # Asignar valores numéricos a los sentimientos
        if sentimiento == "positive":
            valor = 1
        elif sentimiento == "negative":
            valor = -1
        else:
            valor = 0
        
        sentimientos.append(valor * confianza)  # Peso del sentimiento por confianza
        confianzas.append(confianza)

    if confianzas:
        return np.sum(sentimientos) / np.sum(confianzas)  # Media ponderada
    else:
        return 0  # Neutral si no hay datos

# %%
response = client.articles.get_extended_articles(
            params={
                "query": "Bitcoin",  # Puedes cambiar la consulta a un término más general
                "language": "en",
                "from": "2024-06-01",
                "to": "2024-06-31",
                "order": "DESC",
                "pageSize": 5,  # Buscar hasta 5 noticias por día
            }
        )

# %%
response
